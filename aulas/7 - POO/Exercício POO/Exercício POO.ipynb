# %% [markdown]
# ## Proposta

# %% [markdown]
# 1 - escreva uma programa que:

# %% [markdown]
# * Tenha uma classe que simule o funcionamento de uma calculadora

# %% [markdown]
# ### * Métodos da calculadora:

# %% [markdown]
# ##### Somar()
# ##### Subtrair()
# ##### Multiplicar()
# ##### Dividir()
